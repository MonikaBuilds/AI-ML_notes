# %%
#empty list
#we represent the list with square bracket
mylist=[]

# %%
mylist
# Out:
# []

# %%
mylist=[1,2,3,4,5]

# %%
mylist
# Out:
# [1, 2, 3, 4, 5]

# %%
#list with differnt data types
mylist=[1,"hello",2.5]

# %%
mylist
# Out:
# [1, 'hello', 2.5]

# %%
number="10"

# %%
number
# Out:
# '10'

# %%
type(number)
# Out:
# str

# %%
int(number)
# Out:
# 10

# %%
int()
str()
float()
bool()

# %%
#litrable
list(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 #litrable
# ----> 2 list(10)
#
# TypeError: 'int' object is not iterable

# %%
list("sunny")
# Out:
# ['s', 'u', 'n', 'n', 'y']

# %%
list((10,20,30))
# Out:
# [10, 20, 30]

# %%
list([10,20,30])
# Out:
# [10, 20, 30]

# %%
mylist=[1,2,3,4,45,5,6]

# %%
#access the element of list
mylist[4]
# Out:
# 45

# %%
mylist[2:5]
# Out:
# [3, 4, 45]

# %%
mylist[-1]
# Out:
# 6

# %%
mylist[-3]
# Out:
# 45

# %%
mynum=[10,20,30,40,50]
mynum[1:4]
# Out:
# [20, 30, 40]

# %%
mynum[3:5]
# Out:
# [40, 50]

# %%
mynum[2:2]
# Out:
# []

# %%
mynum[2:3]
# Out:
# [30]

# %%
mynum[1:]
# Out:
# [20, 30, 40, 50]

# %%
mynum[:-2]
# Out:
# [10, 20, 30]

# %%
sports=["cricket","hockey","football"]

# %%
#modify the list
sports[1]="badminton"

# %%
sports
# Out:
# ['cricket', 'badminton', 'football']

# %%
sports[1:3]=["basketball","tennis"]

# %%
sports
# Out:
# ['cricket', 'basketball', 'tennis']

# %%
#concatinate 2 lists or strings

# %%
"monika"+" "+"bhati"
# Out:
# 'monika bhati'

# %%
outdoorgames=["cricket","basketball","tennis"]

# %%
indoorgames=["carrom","ludo","chess"]

# %%
all_sports=outdoorgames+indoorgames

# %%
all_sports
# Out:
# ['cricket', 'basketball', 'tennis', 'carrom', 'ludo', 'chess']

# %%
ineuron_team=["sunnyy","krish","sudhanshu"]
ineuron_team+list("satya")
# Out:
# ['sunnyy', 'krish', 'sudhanshu', 's', 'a', 't', 'y', 'a']

# %%
ineuron_team+list(["satya"])
# Out:
# ['sunnyy', 'krish', 'sudhanshu', 'satya']

# %%
ineuron_team+["rishav"]
# Out:
# ['sunnyy', 'krish', 'sudhanshu', 'rishav']

# %%
ineuron_team*3
# Out:
# ['sunnyy',
#  'krish',
#  'sudhanshu',
#  'sunnyy',
#  'krish',
#  'sudhanshu',
#  'sunnyy',
#  'krish',
#  'sudhanshu']

# %%
ineuron_team+3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 ineuron_team+3
#
# TypeError: can only concatenate list (not "int") to list

# %% [markdown]
# #membership operator-in and not in

# %%
ineuron_team
# Out:
# ['sunnyy', 'krish', 'sudhanshu']

# %%
"sunnyy" in ineuron_team
# Out:
# True

# %%
"Rohit" not in ineuron_team
# Out:
# True

# %%
"krish" not in ineuron_team
# Out:
# False

# %%
"S" in "sunnyy"
# Out:
# False

# %%
"s" in "sunnyy"
# Out:
# True

# %% [markdown]
# #list function
# 1. len()
# 2. max()
# 3. min()
# 4. sum()
# 5. sorted()
# 6. all()
# 7. list()
# 8. any()
# #list method
# 1. append()
# 2. extend()
# 3. index()
# 4. insert()
# 5. remove()
# 6. pop()
# 7. clear()
# 8. reverse()
# 9. sor()
# 10. count()
# #list comprehension

# %%
mynum=[1,2,3,4,5,6,7,8]

# %%
#len func gives me length
len(mynum)
# Out:
# 8

# %%
max(mynum)
# Out:
# 8

# %%
min(mynum)
# Out:
# 1

# %%
sum(mynum)
# Out:
# 36

# %%
sorted(mynum)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
sorted(mynum,reverse=True)
# Out:
# [8, 7, 6, 5, 4, 3, 2, 1]

# %% [markdown]
# #if all the elements is true in the list it will give me true otherwise false
# # 0,0.0,False ,0+0j this values will be False in python and
# rest of the value apart from this one will be true

# %%
all(mynum)
# Out:
# True

# %%
mynum3=[0,False,0.0]

# %%
any(mynum3)
# Out:
# False

# %%
mynum3=[0,False,0.0]

# %%
any(mynum3)
# Out:
# False

# %%
primes=[2,3,5,7,11]

# %%
len(primes)
# Out:
# 6

# %% [markdown]
# next prime number will be 13

# %%
primes.append(13)

# %%
primes
# Out:
# [2, 3, 5, 7, 11, 13]

# %%
animal=["dog","cat","rabbit"]

# %%
animal.append("tiger")

# %%
animal
# Out:
# ['dog', 'cat', 'rabbit', 'tiger']

# %%
animal
# Out:
# ['dog', 'cat', 'rabbit']

# %%
wild_animal=["lion","fox"]

# %%
animal.append(wild_animal)

# %%
animal
# Out:
# ['dog', 'cat', 'rabbit']

# %%
animal
# Out:
# ['dog', 'cat', 'rabbit']

# %%
animal+wild_animal
# Out:
# ['dog', 'cat', 'rabbit', 'lion', 'fox']

# %%
animal.extend(wild_animal)

# %%
animal
# Out:
# ['dog', 'cat', 'rabbit', 'lion', 'fox']

# %% [markdown]
# append=any element ,any single element at the end

# %%
animal=["dog","cat","rabbit"]

# %%
animal
# Out:
# ['dog', 'cat', 'rabbit']

# %%
animal[2]
# Out:
# 'rabbit'

# %%
animal[2][0]
# Out:
# 'r'

# %%
mynum=[1,2,3,4,5,6,7]

# %%
mynum.append(1000)

# %%
mynum
# Out:
# [1, 2, 3, 4, 5, 6, 7, 1000]

# %%
mynum.extend(2000)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 mynum.extend(2000)
#
# TypeError: 'int' object is not iterable

# %%
mynum.extend("2000")

# %%
mynum
# Out:
# [1, 2, 3, 4, 5, 6, 7, 1000, '2', '0', '0', '0']

# %%
mynum.extend([2000])

# %%
mynum
# Out:
# [1, 2, 3, 4, 5, 6, 7, 1000, '2', '0', '0', '0', 2000]

# %%
primes=[2,3,5,7,11]

# %%
#modify the list(it is going to overwrite)
primes[3]=9

# %%
primes
# Out:
# [2, 3, 5, 9, 11]

# %% [markdown]
# insert(index,value)
# not overwrite only insert at the given index

# %%
primes.insert(3,1000)

# %%
primes
# Out:
# [2, 3, 5, 1000, 9, 11]

# %%
mynum
# Out:
# [1, 2, 3, 4, 5, 6, 7, 1000, '2', '0', '0', '0', 2000]

# %% [markdown]
# count

# %%
mynum.count('0')
# Out:
# 3

# %%
mynum.count('2')
# Out:
# 1

# %% [markdown]
# #index-you will get index of the given element

# %%
mynum.index(2000)
# Out:
# 12

# %%
len(mynum)-1
# Out:
# 12

# %%
#search for the given element and remove it
#it removes the first matching element
vowels=["a","a","e","i","o","u"]

# %%
vowels.remove("a")

# %%
vowels
# Out:
# ['a', 'e', 'i', 'o', 'u']

# %% [markdown]
# #pop
# pop method removes and returns the element at the given index
# pop(index)

# %%
fruits=["apple","banana","orange"]

# %%
fruits.pop(1)
# Out:
# 'banana'

# %%
fruits
# Out:
# ['apple', 'orange']

# %%
fruits.pop(2)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 fruits.pop(2)
#
# IndexError: pop index out of range

# %%
fruits.pop(1)
# Out:
# 'orange'

# %%
fruits
# Out:
# ['apple']

# %%
fruits.clear()

# %%
fruits
# Out:
# []

# %% [markdown]
# sort-it it going to sort in ascending as well as descending

# %%
mylist=[233,456,789,234,123]

# %%
mylist.sort()

# %%
mylist
# Out:
# [123, 233, 234, 456, 789]

# %%
mylist.sort(reverse=True)

# %%
mylist
# Out:
# [789, 456, 234, 233, 123]

# %% [markdown]
# reverse function-it is going to reverse the element

# %%
mylist.reverse()

# %%
mylist
# Out:
# [123, 234, 789, 456, 233]

# %%
#print this all the element with while as well as for loop
mynum=[45,65,34,5666,77,88,99,78]

# %%
i=0
while i<len(mynum):
    print(mynum[i])
    i+=1
# Out:
# 45
# 65
# 34
# 5666
# 77
# 88
# 99
# 78

# %%
for i in len(mynum):
    print(mynum[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 for i in len(mynum):
#       2     print(mynum[1])
#
# TypeError: 'int' object is not iterable

# %%
for i in mynum:
    print(i)
# Out:
# 45
# 65
# 34
# 5666
# 77
# 88
# 99
# 78
