# %% [markdown]
# ## String- collection of character

# %%
mystring="monika"

# %%
print(mystring)
# Out:
# monika

# %%
mystring
# Out:
# 'monika'

# %%
mystring2="i
love
python"
# Out:
#   Cell In[9], line 1
#     mystring2="i
#               ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
mystring3="""i
love 
python"""

# %%
mystring3   #\n showing next line character
# Out:
# 'i\nlove \npython'

# %%
print(mystring3)
# Out:
# i
# love
# python

# %%
mystrin4=""

# %%
mystrin4
# Out:
# ''

# %%
mystring5=" "

# %%
mystring5
# Out:
# ' '

# %%
mystring6="i love coding"

# %%
len(mystring6)-1
# Out:
# 12

# %%
print(mystring6[4])
# Out:
# v

# %%
mystring6[2:6]
# Out:
# 'love'

# %% [markdown]
# #wap to take input from user and print it in reverse order
# note: dont use slicing operator

# %%
sunny
01234
yunns

# %%
name="sunny"

# %%
len(name)-1
# Out:
# 4

# %%
list(range(len(name)-1,-1,-1))
# Out:
# [4, 3, 2, 1, 0]

# %%
list(range(10,1,-1))
# Out:
# [10, 9, 8, 7, 6, 5, 4, 3, 2]

# %%
for i in range(len(name)-1,-1,-1):
    print(name[i])
# Out:
# y
# n
# n
# u
# s

# %%
name=input("enter your name:")
for i in range(len(name)-1,-1,-1):
    print(name[i])
# Out:
# enter your name: monika
# a
# k
# i
# n
# o
# m

# %% [markdown]
# ## + operator for concatination

# %%
"monika"+" "+"bhati"
# Out:
# 'monika bhati'

# %%
"monika"*"bhati"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 "monika"*"bhati"
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
"monika"*2
# Out:
# 'monikamonika'

# %%
"ba"+"na"*2
# Out:
# 'banana'

# %%
mystring="i ilove my india"

# %%
"love" in mystring
# Out:
# True

# %%
"you" in mystring
# Out:
# False

# %%
" " in mystring
# Out:
# True

# %%
"hindustan" not in mystring
# Out:
# True

# %%
"tim" == "tie"
# Out:
# False

# %%
"free" != "freedom"
# Out:
# True

# %%
"arrow" > "aron"
# Out:
# True

# %%
"right" >= "left"
# Out:
# True

# %%
"teeth" <= "fellow"
# Out:
# False

# %%
"yellow" <="fellow"
# Out:
# False

# %%
"abc" > " "
# Out:
# True

# %% [markdown]
# ## is and is not

# %%
a="monika"
b="monika"

# %%
a is b
# Out:
# True

# %%
c="bhati"

# %%
a is c
# Out:
# False

# %%
a is not c
# Out:
# True

# %% [markdown]
# ## function in string

# %% [markdown]
# #len()
# #max()
# #min()
# #chr()
# #ord()

# %%
mystring="monikabhatiahz"
print(len(mystring))
# Out:
# 14

# %%
max(mystring)
# Out:
# 'z'

# %%
min(mystring)
# Out:
# 'a'

# %%
ord(" ")
# Out:
# 32

# %%
ord("a")
# Out:
# 97

# %%
ord("+")
# Out:
# 43

# %%
ord("10")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 ord("10")
#
# TypeError: ord() expected a character, but string of length 2 found

# %%
ord("5")
# Out:
# 53

# %%
chr(43)
# Out:
# '+'

# %%
chr(97)
# Out:
# 'a'

# %%
chr(110)
# Out:
# 'n'

# %% [markdown]
# ## methods of the string

# %% [markdown]
# # capitalize():Returns a copy of the string with first character capitalized and rest of the character in lower case

# %% [markdown]
# # lower()
# # upper()
#
# # returns a copy of the string with all letters converted to lowercase and uppercase respectively

# %%
name="monika bhati"
lc=name.lower()

# %%
lc
# Out:
# 'monika bhati'

# %%
uc=name.upper()

# %%
uc
# Out:
# 'MONIKA BHATI'

# %% [markdown]
# # swapcase():Returns a copy of the string with the case of every character swapped. Means that lowercase characters are changed to uppercase and vice-versa

# %%
name="monika bhati"

# %%
name.swapcase()
# Out:
# 'MONIKA BHATI'

# %%
mystring="MONIKA BHATI"

# %%
mystring.swapcase()
# Out:
# 'monika bhati'

# %% [markdown]
# # title(): Returns a copy of the string converted to proper case or title case. i.e., all words begin with uppercase letter and the rest are in lowercase

# %%
text = "i love python"

# %%
text.title()
# Out:
# 'I Love Python'

# %% [markdown]
# # islower()
# # isupper()
# # islower() and isupper()
# # Returns True or False depending on whether all alphabets in the string are in lowercase and uppercase respectively

# %%
text="this is good"

# %%
text.islower()
# Out:
# True

# %%
text.isupper()
# Out:
# False

# %%
text="I LOVE PYTHON"

# %%
text.islower()
# Out:
# False

# %%
text.isupper()
# Out:
# True

# %% [markdown]
# # isalpha()
# # returns True if the string contains only alphabets, otherwise returns False

# %%
string="mynameismonikailovescience"

# %%
string.isalpha()
# Out:
# True

# %% [markdown]
# # isdigit()
# # returns True if the string contains only digits, otherwise returns false

# %%
mystring="1234567890"

# %%
mystring.isdigit()
# Out:
# True

# %% [markdown]
# # isalnum()
# # Returns True if the string contains only alphanumeric characters, otherwise returns False

# %%
mystring="monika"

# %%
mystring.isalnum()
# Out:
# True

# %%
mystring2="12345monika"

# %%
mystring2.isalnum()
# Out:
# True

# %%
mystring="monika123"
mystring1="monika"
mystring2="123245"
mystring3="monika123 bhati456"
mystring4="ehrfjk@"

# %%
print(mystring.isalnum())
print(mystring1.isalnum())
print(mystring2.isalnum())
print(mystring3.isalnum())
print(mystring4.isalnum())
# Out:
# True
# True
# True
# False
# False

# %% [markdown]
# # isspace()
# # Returns True if the string contains only whitespace character, otherwise returns False

# %%
string="S"

# %%
string.isspace()
# Out:
# False

# %%
string1=" "

# %%
string1.isspace()
# Out:
# True

# %%
string2=""

# %%
string2.isspace()
# Out:
# False

# %% [markdown]
# # startswith()
# # endswith()

# %%
text="i love machine learning"

# %%
text.startswith("i")
# Out:
# True

# %%
text.endswith("machine")
# Out:
# False

# %%
text.endswith("learning")
# Out:
# True

# %% [markdown]
# # index()
# # returns the index of first occurence of a substring inside the string
# # if the substring is not found, it raises an exception

# %%
text="sunday is fun day fun day"

# %%
text.index("day")
# Out:
# 3

# %% [markdown]
# # count()
# # returns the number of occurences of a substring in the given string

# %%
text="python is awesome. isn't it?, is it true"

# %%
text.count("is")
# Out:
# 3

# %% [markdown]
# # split()

# %%
"i@love@my@india".split("@")
# Out:
# ['i', 'love', 'my', 'india']

# %% [markdown]
# # join()

# %%
"@".join(["m","o","n","i"])
# Out:
# 'm@o@n@i'

# %%
"@".join("monika")
# Out:
# 'm@o@n@i@k@a'

# %%
name="monika"
age=19
print("my name is",name, "and my age is",age)
# Out:
# my name is monika and my age is 19

# %% [markdown]
# # f-string
# # string interpolation

# %%
# time complexity is very less
print(f"my name is {name} my age is {age}")
# Out:
# my name is monika my age is 19

# %%
a=10
b=20

# %%
print(f"my first number is {a} and my max number is {b}")
# Out:
# my first number is 10 and my max number is 20

# %%
a=10
b=20
if a > b:
    print(f)
