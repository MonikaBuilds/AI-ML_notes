# %% [markdown]
# wap to accept two numbers from the user and display their sum

# %%
a=int(input("enter the first number:"))
b=int(input("enter the second number:"))
c=a+b
print(c)
# Out:
# enter the first number: 5
# enter the second number: 6
# 11

# %% [markdown]
# wap to accept radius of a circle from the user and calculate area and circumference

# %%
r=float(input("enter the radius :"))
area=3.14*r*r
circumference=2*3.14*r
area,circumference
# Out:
# enter the radius : 4
# (50.24, 25.12)

# %%
import math
radius =float(input("enter the radius :"))
print("area is",math.pi*radius*radius)
print("circumference is",2*math.pi*radius)
# Out:
# enter the radius : 4
# area is 50.26548245743669
# circumference is 25.132741228718345

# %% [markdown]
# wap to accept roll number,grade and percentage as input from the user and display it bac

# %%
a=int(input("enter your roll number:"))
b=int(input("enter your grade:"))
c=int(input("enter your percentage:"))
print("your roll number is:",a)
print("your grade is:",b)
print("your percentage is:",c)
# Out:
# enter your roll number: 5
# enter your grade: 5
# enter your percentage: 67
# your roll number is: 5
# your grade is: 5
# your percentage is: 67

# %% [markdown]
# wap that asks the user to enter his/her name and age.print out a message, displaying
# the user's name along with the year in which they will turn 100 years old.

# %%
name=input("enter your name:")
age=int(input("enter your age:"))
year=(2025-age)+100
print(f"your name is {name},and your are going to be 100 years old in {year}")
# Out:
# enter your name: monika
# enter your age: 19
# your name is monika,and your are going to be 100 years old in 2106

# %%
name=input("enter your name:")
age=int(input("enter your age:"))
year=(2025-age)+100
print("your name is {name} and your are going to be 100 years old in {year}".format(name=name,year=year))
# Out:
# enter your name: monika
# enter your age: 19
# your name is monika and your are going to be 100 years old in 2106

# %% [markdown]
# wap that asks the user to input 2 integers and adds them.
# accept both the number in a single line only

# %%
a,b=input("enter two numbers;").split()
print(int(a)+int(b))
# Out:
# enter two numbers; 4 5
# 9

# %% [markdown]
# wap which accepts the user's first and last name and print them in reverse order with
# a space between them

# %%
Fname=input()
Lname=input()
print(Fname[::-1],'',Lname[::-1])
# Out:
#  mansi
#  bhati
# isnam  itahb

# %%
x="mansi"

# %%
x[::1]
# Out:
# 'mansi'

# %%
x[2:4]
# Out:
# 'ns'

# %%
x[::-1]
# Out:
# 'isnam'

# %%
x[1::]
# Out:
# 'ansi'

# %% [markdown]
# wap to accept an integer from the user and check whether it is even or odd

# %%
i=int(input("enter an integer:"))
if(i%2)==0:
    print("even")
else:
    print("odd")
# Out:
# enter an integer: 5
# odd

# %% [markdown]
# wap to accept a character from the user and check whether it is a capital letter
# or small letter .assume user will input only alphabets.

# %%
n=input("Enter the character:")
if n.upper()==n:
    print("the given character is in capital letter")
else:
    print("the given character is in small letter")
# Out:
# Enter the character: a
# the given character is in small letter

# %%
ch=input("enter the character:")
if "A"<=ch<="Z":
    print("capital")
else:
    print("small")
# Out:
# enter the character: M
# capital

# %% [markdown]
# wap to accept a character from the user and check whether it is a capital letter
# or small letter or a digit or some special symbol

# %%
ch=input("enter a character:")
if ch.isupper():
    print("it is a uppercase character")
elif ch.islower():
    print("it is a lowercase character")
elif ch.isdigit():
    print("it is a digit")
else:
    print("special symbol")
# Out:
# enter a character: 3
# it is a digit

# %%
ch=input("enter a character:")
if ch.isupper():
    print("it is a uppercase character")
elif ch.islower():
    print("it is a lowercase character")
elif ch.isdigit():
    print("it is a digit")
else:
    print("special symbol")
# Out:
# enter a character: @
# special symbol

# %%
x="A"
x.isupper()
# Out:
# True

# %%
x="a"
x.isupper()
# Out:
# False

# %%
char=input("enter the character of your's choice:")
if "A"<=char<="Z":
    print("enter character %s is capital alphabet"%(char))
elif "a"<=char<="z":
    print("enter character %s is small alphabet"%(char))
elif '0'<=char<='9':
    print("digit")
else:
    print("some special character"%(char))
# Out:
# enter the character of your's choice: 5
# digit

# %% [markdown]
# wap to accept 3 integers from the user and without using any logical
# operator and cascading of relational operators , find out greatest number among them

# %%
n1=int(input("enter a number1:"))
n2=int(input("enter a number2:"))
n3=int(input("enter a number3:"))
if n1>n3:
    print("n1 is greatest:",n1)
elif n2>n1:
    if n2>n3:
        print("n2 is greatest:",n2)
    else:
        print("n3 is greatest:",n3)
# Out:
# enter a number1: 3
# enter a number2: 4
# enter a number3: 5
# n3 is greatest: 5

# %% [markdown]
# wap to accept a year from the user and check whether it is a leap year or not
# an year is a leap year if:
# it is exacatly divisible by 4 and at the same time not divisible by 100
# or
# it is divisible by 400
# for example:
# 2017 is not a leap year
# 2012 is a leap year
# 1900 is not a leap year
# 2000 is a leap year

# %%
year=input("Enter to check whether it is a leap year or not:")
if year[2]==0:
    if year[3]==0:
        out=year%400
        print("{} is a leap year".format(year))
elif int(year)%4==0:
        print("{} is a leap year".format(year))
else:
    print("{} is not a leap year".format(year))
# Out:
# Enter to check whether it is a leap year or not: 2017
# 2017 is not a leap year

# %%
n=int(input("Enter to check whether it is a leap year or not:"))
if (n%4==0 and n%100!=0) or n%400==0:
    print("leap year")
else:
    print("not a leap year")
# Out:
# Enter to check whether it is a leap year or not: 2000
# leap year

# %% [markdown]
# you have to develop a number guessing game.following are the steps needed:
# At first, the program will generate a random integer secretly.
# now it will ask the user to guess that number.
# if the user guessed it correctly then the program prints "congratulations!
# you guessed it right.
# But if the number guessed by the user is larger than the secret number
# then program should print "number too larger" and if the number guessed by
# the user is smaller than the secret number then the program should print
# "number too small"
# This should continue until the user guesses the number correctly or quits
# If the user wants to quit in between he will have to type 0 or negative number

# %%
import random
a=random.randint(1,5)
while(1):
    n=int(input("guess that number:"))
    if n==a:
        print("congratulations!you guessed it right")
        break
    elif n>a:
        print("number too large")
    elif n<a:
        print("number too small")
    else:
        break
# Out:
# guess that number: 4
# number too small
# guess that number: 5
# congratulations!you guessed it right

# %%
print(a)
# Out:
# 5

# %%
a=random.randint(1,10)
print(a)
# Out:
# 1

# %% [markdown]
# wap to accept a string from the user and display it vertically but don't display vowels in it

# %%
n=input("enter a string")
a=0
while(a<len(n)):
    if n[a]!='a' and n[a]!='e' and n[a]!="i" and n[a]!='o' and n[a]!='u':
        print(n[a])
    a+=1
# Out:
# enter a string monika
# m
# n
# k

# %% [markdown]
# wap to continuously accept integers from the user until the user types 0 and as soon as
# 0 is entered display sum of all the numbers entered before 0
# note: Modify the previous code so that if the user inputs a negative integer your program
# should ignore it.

# %%
sum=0
while(1):
    n=int(input("enter a number:"))
    if n==0:
        print("sum is",sum)
        break
    sum=sum+n
# Out:
# enter a number: 4
# enter a number: 5
# enter a number: 6
# enter a number: 6
# enter a number: 0
# sum is 21

# %% [markdown]
# wap using a for loop to accept a string from the user and display it vertically but
# don't display the vowels in it.

# %%
string=input("enter a string:")
for i in string:
    if i not in 'aeiouAEIOU':
        print(i)
# Out:
# enter a string: monika
# m
# n
# k

# %% [markdown]
# wap to accept an intger from the user and display the sum of all the numbers from 1 to that
# number

# %%
a=int(input("enter the number:"))
print("sum is",(n*(n+1))/2)
# Out:
# enter the number: 6
# sum is 0.0

# %%
a=int(input("enter the number:"))
sum=0
for i in range(1,a+1):
    sum=sum+i
print(sum)
# Out:
# enter the number: 3
# 6

# %%
data types:
numbers: int,float,complex
list,tuple(2,'monika',bool),set,dictionary,string

# %%
x=[2,'monika',True]
type(x)
# Out:
# list

# %%
print(x)
# Out:
# [2, 'monika', True]

# %%
capitals={'rajasthan':'Pali','jodhpur':'mumbai',2:"two"}
type(capitals)
# Out:
#   Cell In[13], line 1
#     capitals={'rajasthan':'karnataka','mumbai',2:"two"}
#                                              ^
# SyntaxError: ':' expected after dictionary key
