# %%
a="monika"

# %%
a[4]
# Out:
# 'k'

# %%
a[3]
# Out:
# 'i'

# %%
a[1]
# Out:
# 'o'

# %%
a[-1]
# Out:
# 'a'

# %%
len(a)
# Out:
# 6

# %%
len(a)-1
# Out:
# 5

# %%
a="Monika"

# %%
b="Bhati"

# %%
c=a+b

# %%
print(c)
# Out:
# MonikaBhati

# %%
c=a+" "+b

# %%
print(c)
# Out:
# Monika Bhati

# %%
a="monika"

# %%
len(a)-1
# Out:
# 5

# %%
a[1:5]
#slicing
# Out:
# 'onik'

# %%
a[0:6]
# Out:
# 'monika'

# %%
s="industry"
print(s[2:6])
# Out:
# dust

# %%
word="python"

# %%
word[2:3]
# Out:
# 't'

# %%
s="welcome"

# %%
s[1:]
# Out:
# 'elcome'

# %%
s[:3]
# Out:
# 'wel'

# %%
s[]
# Out:
#   Cell In[27], line 1
#     s[]
#       ^
# SyntaxError: invalid syntax

# %%
s[:]
# Out:
# 'welcome'

# %%
s[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 s[10]
#
# IndexError: string index out of range

# %%
s[10:]
# Out:
# ''

# %%
s[-4:-1]
# Out:
# 'com'

# %%
s[-1:-4]
# Out:
# ''

# %%
a="my name is monika"

# %%
a[11:18]
# Out:
# 'monika'

# %%
len(a)-1
# Out:
# 16

# %%
a="monika"

# %%
a[0:7:2]
# Out:
# 'mnk'

# %%
a[0:7:3]
# Out:
# 'mi'

# %%
a[0:6:2]
# Out:
# 'mnk'

# %%
a[-1:-4]
# Out:
# ''

# %%
a[-4:-1]
# Out:
# 'nik'

# %%
a[::-1]
# Out:
# 'akinom'

# %%
a="we are here for learning data science"

# %%
a[::-1]
# Out:
# 'ecneics atad gninrael rof ereh era ew'

# %%
a[-1:-22:-1]
# Out:
# 'ecneics atad gninrael'

# %%
a[37:15:1]
# Out:
# ''

# %%
a[-22:-1:1]
# Out:
# ' learning data scienc'

# %%
x=5
y=3
print(x+y)
print(x-y)
print(x*y)
print(x/y)
print(x%y)
print(x**y) #5 raise to 3
print(x//y) #rounds the result down to the nearest whole number
# Out:
# 8
# 2
# 15
# 1.6666666666666667
# 2
# 125
# 1

# %%
a=10
b=4
print("a=",a,"b=",b)
# Out:
# a= 10 b= 4

# %%
print("a>b",a>b)
# Out:
# a>b True

# %%
print("a<b",a<b)
# Out:
# a<b False

# %%
print("a==b",a==b)
# Out:
# a==b False

# %%
print("a!=b",a!=b)
# Out:
# a!=b True

# %%
print("a>=b",a>=b)
# Out:
# a>=b True

# %%
print("a<=b",a<b)
# Out:
# a<=b False

# %%
a="s"

# %%
ord(a)
# Out:
# 115

# %%
print(-1>6>5)
# Out:
# False

# %%
True and False
# Out:
# False

# %%
True and True
# Out:
# True

# %%
False and True
# Out:
# False

# %%
False and False
# Out:
# False

# %%
x=y=z=10

# %%
x
# Out:
# 10

# %%
y
# Out:
# 10

# %%
z
# Out:
# 10

# %%
X=50

# %%
X+10
# Out:
# 60

# %%
X=+10

# %%
X
# Out:
# 10

# %%
X=10

# %%
X=X**5

# %%
X
# Out:
# 100000

# %%
a=10
print(++a)
# Out:
# 10

# %%
a=10
print(a++)
# Out:
#   Cell In[86], line 2
#     print(a++)
#              ^
# SyntaxError: invalid syntax

# %%
a=10

# %%
id(a)
# Out:
# 140728383318744

# %%
b=20

# %%
id(b)
# Out:
# 140728383319064

# %%
a is b
# Out:
# False

# %%
a is not b
# Out:
# True

# %%
x=5

# %%
y=5

# %%
x is y
# Out:
# True

# %%
x is not y
# Out:
# False

# %%
x=5.5
y=5.5

# %%
x is y
# Out:
# False

# %%
a=str(input("Enter your name"))
b=int(input("enter your age"))
c=(2025-b)+100
print("name is:",a,"and year:",c)
# Out:
# Enter your name monika bhati
# enter your age 19
# name is: monika bhati and year: 2106

# %%
name=input("enter your name")
age=int(input("enter your age"))
NumberOfYearNeed = 100-age
currentyear=2025
yearNeeded = currentyear + NumberOfYearNeed
print(name,yearNeeded)
# Out:
# enter your name monika bhati
# enter your age 19
# monika bhati 2106

# %%
#write a python program which accepts the users first and last name and print them in reverse order with a space between them

# %%
fname = input("enter your first name:")
lname = input("enter your last name:")
print("Hello " + lname + " " + fname)
# Out:
# enter your first name: monika
# enter your last name: bhati
# Hello bhati monika

# %%
first_name = input("enter the first name:")
last_name = input("enter the last name:")
rev1 = first_name[::-1]
rev2 = last_name[::-1]
print(f"{rev2} {rev1}")
# Out:
# enter the first name: monika
# enter the last name: bhati
# itahb akinom

# %%
a=input("enter your first name:")
b=input("enter your last name:")
print(b[::-1]+" " + a[::-1])
# Out:
# enter your first name: monika
# enter your last name: bhati
# itahb akinom
