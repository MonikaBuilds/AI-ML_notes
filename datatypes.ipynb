# %%
a=10
type(a)
# Out:
# int

# %%
b=10.45
type(b)
# Out:
# float

# %%
c="Monika"
type(c)
# Out:
# str

# %%
d="A"
type(d)
# Out:
# str

# %%
a=1234.5555
type(a)
# Out:
# float

# %%
a=2
getsizeof(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 a=2
# ----> 2 getsizeof(a)
#
# NameError: name 'getsizeof' is not defined

# %%
a=2

# %%
import sys
sys.getsizeof(a)
# Out:
# 28

# %%
a=20000

# %%
import sys
sys.getsizeof(a)
# Out:
# 28

# %%
a=2323232323232
import sys
sys.getsizeof(a)
# Out:
# 32

# %%
a=2323232333333333333333333333333333333333333333333333333333333333333333333333333333333333333333333333333333

# %%
type(a)
# Out:
# int

# %%
import sys
sys.getsizeof(a)
# Out:
# 72

# %%
a=false
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 a=false
#
# NameError: name 'false' is not defined

# %%
a=False

# %%
type(a)
# Out:
# bool

# %%
a=true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 a=true
#
# NameError: name 'true' is not defined

# %%
a=True

# %%
type(a)
# Out:
# bool

# %%
1+1
# Out:
# 2

# %%
True+True
# Out:
# 2

# %%
True+False
# Out:
# 1

# %%
False+True
# Out:
# 1

# %%
False+False
# Out:
# 0

# %%
a=True

# %%
import sys
sys.getsizeof(a)
# Out:
# 28

# %%
a="Monika"

# %%
type(a)
# Out:
# str

# %%
a='Monika'

# %%
type(a)
# Out:
# str

# %%
a="monika'
# Out:
#   Cell In[32], line 1
#     a="monika'
#       ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
msg='monika's python classes'
# Out:
#   Cell In[33], line 1
#     msg='monika's python classes'
#                                 ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
msg="monika's pythone class"

# %%
msg
# Out:
# "monika's pythone class"

# %%
msg='monika"s class'

# %%
msg
# Out:
# 'monika"s class'

# %%
y="""let's learn "python" """

# %%
type(y)
# Out:
# str

# %%
y='''let's learn "python" '''

# %%
type(y)
# Out:
# str

# %%
y= 'let\'s learn "python" '

# %%
type(y)
# Out:
# str

# %%
my_string="my
            name
            is
            monika"
# Out:
#   Cell In[48], line 1
#     my_string="my
#               ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
my_string= """my
            name
            is
            monika"""

# %%
print(my_string)
# Out:
# my
#             name
#             is
#             monika

# %%
a=100

# %%
type(a)
# Out:
# int

# %%
b=float(a)

# %%
type(b)
# Out:
# float

# %%
print(b)
# Out:
# 100.0

# %%
a='10'

# %%
type(a)
# Out:
# str

# %%
b='20'

# %%
a+b
# Out:
# '1020'

# %%
x=int('10')

# %%
type(x)
# Out:
# int

# %%
y=int('20')

# %%
type(y)
# Out:
# int

# %%
x+y
# Out:
# 30

# %%
input("first number:")
input("second number:")
c=a-b
print(c)
# Out:
# first number: 40
# second number: 20
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 3
#       1 input("first number:")
#       2 input("second number:")
# ----> 3 c=a-b
#       4 print(c)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
input("first number:")
input("second number:")
c=a-b
print(c)
# Out:
# first number: 40
# second number: 20
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 3
#       1 input("first number:")
#       2 input("second number:")
# ----> 3 c=a-b
#       4 print(c)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
input()
# Out:
#  10
# '10'

# %%
a=int(input("first no.:"))
b=int(input("second no.:"))
c=a-b
print(c)
# Out:
# first no.: 40
# second no.: 20
# 20

# %%
a=10

# %%
b=0.5

# %%
c=a+b

# %%
type(c)
# Out:
# float

# %%
print(c)
# Out:
# 10.5

# %%
a="monika"

# %%
b=10

# %%
a+b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 a+b
#
# TypeError: can only concatenate str (not "int") to str

# %%
a="monika"

# %%
b="10"

# %%
a+b
# Out:
# 'monika10'

# %%
complex(25)
# Out:
# (25+0j)

# %%
complex(2.5)
# Out:
# (2.5+0j)

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex(False)
# Out:
# 0j

# %%
bool(1)
# Out:
# True

# %%
bool(0.0)
# Out:
# False

# %%
bool(5
