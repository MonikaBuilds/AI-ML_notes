# %% [markdown]
# ## dictionary

# %%
list=[]
typle=()
set={}
string=" "

# %% [markdown]
# key: value pair
#
# ## dictionary: dictionary is a collection which holds data in pair(that pair will be in key and value)
#
# if i want to connect one piece of information with other place of information so we always use distionary
#
# ex: rollno->student
#
#     name-> mobile number

# %% [markdown]
# # syntax of dictionary
#
# dict= { key1:value1,
#
#  key2:value2,
#
#  key3:value3,
#
#  ....
#
#  keyn:valuen
#
# }

# %%
mydict={}

# %%
type(mydict)
# Out:
# dict

# %%
# dict of int key
mydict1={1:"monika",2:"mansi",3:"Reshma"}

# %%
mydict1
# Out:
# {1: 'monika', 2: 'mansi', 3: 'Reshma'}

# %%
mydict2={1:"monika","a":"mansi"}

# %%
mydict2
# Out:
# {1: 'monika', 'a': 'mansi'}

# %%
mydict3={"rahul":["c","c++"],"rohit":["Java","java script"],"sunny":["python","machine learning"]}

# %%
mydict3
# Out:
# {'rahul': ['c', 'c++'],
#  'rohit': ['Java', 'java script'],
#  'sunny': ['python', 'machine learning']}

# %%
mydict3["rahul"]
# Out:
# ['c', 'c++']

# %%
mydict3.get("sunny")
# Out:
# ['python', 'machine learning']

# %%
student_data={1:"amit",2:"brajesh",3:"chetan",4:"deepak",5:"neeraj"}

# %%
student_data
# Out:
# {1: 'amit', 2: 'brajesh', 3: 'chetan', 4: 'deepak', 5: 'neeraj'}

# %%
for i in student_data.keys():
    print("my key is:",i)
# Out:
# my key is: 1
# my key is: 2
# my key is: 3
# my key is: 4
# my key is: 5

# %%
for i in student_data.values():
    print("my value is:",i)
# Out:
# my value is: amit
# my value is: brajesh
# my value is: chetan
# my value is: deepak
# my value is: neeraj

# %%
for x in student_data.values():
    print(x)
# Out:
# amit
# brajesh
# chetan
# deepak
# neeraj

# %%
for x in student_data.items():
    print(x)
# Out:
# (1, 'amit')
# (2, 'brajesh')
# (3, 'chetan')
# (4, 'deepak')
# (5, 'neeraj')

# %% [markdown]
# key
# value
# key and value

# %%
student_data={1:"amit",2:"brajesh",3:"chetan",4:"deepak",5:"neeraj"}

# %% [markdown]
# # if we want to update any new key value pair in dict we use subscript operator or update function

# %%
student_data
# Out:
# {1: 'amit', 2: 'brajesh', 3: 'chetan', 4: 'deepak', 5: 'neeraj'}

# %%
student_data[6]="monika"

# %%
student_data
# Out:
# {1: 'amit', 2: 'brajesh', 3: 'chetan', 4: 'deepak', 5: 'neeraj', 6: 'monika'}

# %%
student_data.update({7:"zoha"})

# %%
student_data
# Out:
# {1: 'amit',
#  2: 'brajesh',
#  3: 'chetan',
#  4: 'deepak',
#  5: 'neeraj',
#  6: 'monika',
#  7: 'zoha'}

# %%
student_data[2]="mansi bhati"

# %%
student_data
# Out:
# {1: 'amit',
#  2: 'mansi bhati',
#  3: 'chetan',
#  4: 'deepak',
#  5: 'neeraj',
#  6: 'monika',
#  7: 'zoha'}

# %% [markdown]
# # if key is not available then it will create new pair if it is available then it will overwrite

# %% [markdown]
# # function for the dictionary
#
# len()
#
# max()
#
# min()
#
# any()
#
# all()
#
# sorted()
#
# dict()

# %%
sixmonths = {"Jan":31,"Feb":28,"Mar":31,"Apr":30,"May":31,"Jun":30}

# %%
sixmonths.items()
# Out:
# dict_items([('Jan', 31), ('Feb', 28), ('Mar', 31), ('Apr', 30), ('May', 31), ('Jun', 30)])

# %%
sixmonths
# Out:
# {'Jan': 31, 'Feb': 28, 'Mar': 31, 'Apr': 30, 'May': 31, 'Jun': 30}

# %%
len(sixmonths)
# Out:
# 6

# %%
max(sixmonths)
# Out:
# 'May'

# %%
max(sixmonths.values())
# Out:
# 31

# %%
m will be greater among all 

lexigraphic comparison

# %%
min(sixmonths)
# Out:
# 'Apr'

# %%
any(sixmonths)
# Out:
# True

# %%
all(sixmonths)
# Out:
# True

# %%
sorted(sixmonths)
# Out:
# ['Apr', 'Feb', 'Jan', 'Jun', 'Mar', 'May']

# %%
dict(sixmonths)
# Out:
# {'Jan': 31, 'Feb': 28, 'Mar': 31, 'Apr': 30, 'May': 31, 'Jun': 30}

# %% [markdown]
# # methods in dictionary
#
# clear()
#
# copy()
#
# setdefault()
#
# get()
#
# keys()
#
# values()
#
# items()
#
# updated()
#
# pop()
#
# popitems()

# %%
sixmonths = {"Jan":31,"Feb":28,"Mar":31,"Apr":30,"May":31,"Jun":30}

# %%
sixmonths.pop("Jan")
# Out:
# 31

# %%
sixmonths
# Out:
# {'Feb': 28, 'Mar': 31, 'Apr': 30, 'May': 31, 'Jun': 30}

# %%
sixmonths.pop("nov")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 sixmonths.pop("nov")
#
# KeyError: 'nov'

# %%
sixmonths.pop("nov","not found")
# Out:
# 'not found'

# %%
sixmonths.pop("Feb","Not found")
# Out:
# 28

# %%
sixmonths
# Out:
# {'Mar': 31, 'Apr': 30, 'May': 31, 'Jun': 30}

# %%
sixmonths.popitem()  #bydefault it vanishes last item
# Out:
# ('Jun', 30)

# %%
sixmonths
# Out:
# {'Mar': 31, 'Apr': 30, 'May': 31}

# %%
sixmonths.popitem()
# Out:
# ('May', 31)

# %%
sixmonths
# Out:
# {'Mar': 31, 'Apr': 30}

# %%
sixmonths.clear()

# %%
sixmonths
# Out:
# {}

# %%
sixmonths = {"Jan":31,"Feb":28,"Mar":31,"Apr":30,"May":31,"Jun":30}

# %%
new=sixmonths.copy()

# %%
new
# Out:
# {'Jan': 31, 'Feb': 28, 'Mar': 31, 'Apr': 30, 'May': 31, 'Jun': 30}

# %%
value = cars={"Maruti":"Ciaz","Hyundai":"Verna","Honda":"Amaze"}

# %%
value = cars.setdefault("Hyundai")

# %%
value
# Out:
# 'Verna'

# %%
value=cars.setdefault("Renault")

# %%
value

# %%
cars
# Out:
# {'Maruti': 'Ciaz',
#  'Hyundai': 'Verna',
#  'Honda': 'Amaze',
#  'Hondai': None,
#  'Renault': None}

# %%
value=cars.setdefault("Renault","duster")

# %%
cars
# Out:
# {'Maruti': 'Ciaz',
#  'Hyundai': 'Verna',
#  'Honda': 'Amaze',
#  'Hondai': None,
#  'Renault': None}
