# %%
import pandas as pd
data=pd.read_csv("cleaned_google_playstore_data.csv")

# %%
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10352                                   Sya9a Maroc - FR               FAMILY
# 10353                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10354                             Parkinson Exercices FR              MEDICAL
# 10355                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10356      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
data=pd.read_csv("https://raw.githubusercontent.com/sunnysavita10/Statistics-With-Python-CompleteGuide/refs/heads/main/googleplaystore.csv")

# %%
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
data_copy=data.copy()

# %%
data_copy[data_copy.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10768                                             AAFP       MEDICAL     3.8
#
# ...

# %%
data_copy.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
data_copy[data_copy["App"].duplicated()]
# Out:
#                                       App       Category  Rating Reviews  \
# 229          Quick PDF Scanner + OCR FREE       BUSINESS     4.2   80805
# 236                                   Box       BUSINESS     4.2  159872
# 239                    Google My Business       BUSINESS     4.4   70991
# 256                   ZOOM Cloud Meetings       BUSINESS     4.4   31614
# 261             join.me - Simple Meetings       BUSINESS     4.0    6989
# ...                                   ...            ...     ...     ...
# 10715                  FarmersOnly Dating         DATING     3.0    1145
# 10720  Firefox Focus: The privacy browser  COMMUNICATION     4.4   36981
# 10730                         FP Notebook        MEDICAL     4.5     410
# 10753      Slickdeals: Coupons & Shopping       SHOPPING     4.5   33599
# 10768                                AAFP        MEDICAL     3.8      63
#
#                      Size     Installs  Type Price Content Rating  \
# ...

# %%
len(data_copy[data_copy["App"].duplicated()])
# Out:
# 1181

# %%
for col in data_copy.columns:
    print(f" here is number of duplicated values {col} {len(data_copy[data_copy["App"].duplicated()])}")
# Out:
#  here is number of duplicated values App 1181
#  here is number of duplicated values Category 1181
#  here is number of duplicated values Rating 1181
#  here is number of duplicated values Reviews 1181
#  here is number of duplicated values Size 1181
#  here is number of duplicated values Installs 1181
#  here is number of duplicated values Type 1181
#  here is number of duplicated values Price 1181
#  here is number of duplicated values Content Rating 1181
#  here is number of duplicated values Genres 1181
#  here is number of duplicated values Last Updated 1181
#  here is number of duplicated values Current Ver 1181
#  here is number of duplicated values Android Ver 1181

# %%
data_copy=data_copy.drop_duplicates(subset=["App"],keep="first")

# %%
data_copy
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9660 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9660 non-null   object
#  1   Category        9660 non-null   object
#  2   Rating          8197 non-null   float64
#  3   Reviews         9660 non-null   object
#  4   Size            9660 non-null   object
#  5   Installs        9660 non-null   object
#  6   Type            9659 non-null   object
#  7   Price           9660 non-null   object
#  8   Content Rating  9659 non-null   object
#  9   Genres          9660 non-null   object
#  10  Last Updated    9660 non-null   object
#  11  Current Ver     9652 non-null   object
#  12  Android Ver     9657 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 1.0+ MB

# %%
numeric_feature=[feature for feature in data_copy.columns if data_copy[feature].dtype!="O"]

# %%
numeric_feature
# Out:
# ['Rating']

# %%
data_categorical=data_copy[numeric_feature]

# %%
data_categorical
# Out:
#        Rating
# 0         4.1
# 1         3.9
# 2         4.7
# 3         4.5
# 4         4.3
# ...       ...
# 10836     4.5
# 10837     5.0
# 10838     NaN
# 10839     4.5
# 10840     4.5
#
# [9660 rows x 1 columns]

# %%
data_copy.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
data_copy["Type"].value_counts(normalize=True)
# Out:
# Type
# Free    0.921627
# Paid    0.078269
# 0       0.000104
# Name: proportion, dtype: float64

# %%
data_copy["Type"].value_counts(normalize=True)*100     #normalize value-%value
# Out:
# Type
# Free    92.162750
# Paid     7.826897
# 0        0.010353
# Name: proportion, dtype: float64

# %%
data_categorical["Rating"]
# Out:
# 0        4.1
# 1        3.9
# 2        4.7
# 3        4.5
# 4        4.3
#         ...
# 10836    4.5
# 10837    5.0
# 10838    NaN
# 10839    4.5
# 10840    4.5
# Name: Rating, Length: 9660, dtype: float64

# %%
data_copy["Category"].value_counts(normalize=True)*100
# Out:
# Category
# FAMILY                 18.964803
# GAME                    9.927536
# TOOLS                   8.561077
# BUSINESS                4.347826
# MEDICAL                 4.089027
# PERSONALIZATION         3.892340
# PRODUCTIVITY            3.871636
# LIFESTYLE               3.819876
# FINANCE                 3.571429
# SPORTS                  3.364389
# COMMUNICATION           3.260870
# HEALTH_AND_FITNESS      2.981366
# PHOTOGRAPHY             2.908903
# NEWS_AND_MAGAZINES      2.629400
# SOCIAL                  2.474120
# BOOKS_AND_REFERENCE     2.298137
# TRAVEL_AND_LOCAL        2.267081
# SHOPPING                2.091097
# DATING                  1.770186
# VIDEO_PLAYERS           1.687371
# MAPS_AND_NAVIGATION     1.356108
# EDUCATION               1.231884
# FOOD_AND_DRINK          1.159420
# ENTERTAINMENT           1.055901
# AUTO_AND_VEHICLES       0.879917
# LIBRARIES_AND_DEMO      0.869565
# WEATHER                 0.817805
# HOUSE_AND_HOME          0.766046
# ...

# %%
data_copy["App"].value_counts()
# Out:
# App
# iHoroscope - 2018 Daily Horoscope & Astrology         1
# Photo Editor & Candy Camera & Grid & ScrapBook        1
# Coloring book moana                                   1
# U Launcher Lite – FREE Live Cool Themes, Hide Apps    1
# Sketch - Draw & Paint                                 1
#                                                      ..
# Photo Designer - Write your name with shapes          1
# Learn To Draw Kawaii Characters                       1
# 3D Color Pixel by Number - Sandbox Art Coloring       1
# Mandala Coloring Book                                 1
# Tattoo Name On My Photo Editor                        1
# Name: count, Length: 9660, dtype: int64

# %%
import seaborn as sns
sns.countplot(x=data_copy["Type"])
# Out:
# <Axes: xlabel='Type', ylabel='count'>

# %%
data_copy["Content Rating"].value_counts()
# Out:
# Content Rating
# Everyone           7903
# Teen               1036
# Mature 17+          393
# Everyone 10+        322
# Adults only 18+       3
# Unrated               2
# Name: count, dtype: int64

# %%
sns.countplot(x=data_copy["Content Rating"])
# Out:
# <Axes: xlabel='Content Rating', ylabel='count'>

# %% [markdown]
# univariate
# bivariate
# multi variate analysis

# %%
import matplotlib.pyplot as plt 
plt.figure(figsize=(20,15))
plt.suptitle("Univariate Analysis of Categorical Features",fontsize=20,fontweight='bold',alpha=0.8,y=1)
category=['Type','Content Rating']
for i in range(0,len(category)):
    plt.subplot(2,2,i+1)
    sns.countplot(x=data_copy[category[i]],palette="Set2")
    plt.xlabel(category[i])
    plt.xticks(rotation=45)
    plt.tight_layout()
# Out:
# C:\Users\monika Bhati\AppData\Local\Temp\ipykernel_15136\1170793613.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data_copy[category[i]],palette="Set2")
# C:\Users\monika Bhati\AppData\Local\Temp\ipykernel_15136\1170793613.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data_copy[category[i]],palette="Set2")

# %%
data_num = data_copy.select_dtypes(include=['int64', 'float64'])

# %%
data_num
# Out:
#        Rating
# 0         4.1
# 1         3.9
# 2         4.7
# 3         4.5
# 4         4.3
# ...       ...
# 10836     4.5
# 10837     5.0
# 10838     NaN
# 10839     4.5
# 10840     4.5
#
# [9660 rows x 1 columns]

# %%
sns.kdeplot(data_num["Rating"])
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
sns.histplot(data_num["Rating"])
# Out:
# <Axes: xlabel='Rating', ylabel='Count'>

# %%
sns.distplot(data_num["Rating"])
# Out:
# C:\Users\monika Bhati\AppData\Local\Temp\ipykernel_15136\3656147139.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_num["Rating"])
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
#i want to do normal distribution
import numpy as np
sns.distplot(np.log(data_num["Rating"]))
# Out:
# C:\Users\monika Bhati\AppData\Local\Temp\ipykernel_15136\2165476445.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(data_num["Rating"]))
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15, 15))
plt.suptitle("Univariate Analysis of Numerical Features", fontsize=20, fontweight='bold', alpha=0.8, y=1.02)

for i in range(0, len(numeric_feature)):
    plt.subplot(5, 3, i+1)             #5rows 3columns = max 15 features
    sns.kdeplot(x=data_copy[numeric_feature[i]], fill=True, color='r')  # Fixed: shade -> fill
    plt.xlabel(numeric_feature[i])
    plt.tight_layout()

# %%
data_copy["Category"].value_counts().plot.pie(y=data_copy["Category"],figsize=(15,15),autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
#which category app users are reviewing the most

# %%
data_copy.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews Size  Installs  Type Price Content Rating  \
# 0     159  19M   10,000+  Free     0       Everyone
# 1     967  14M  500,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
df_cat=data_copy['Category'].value_counts()[:10]   #i want top 10 app category

# %%
df_cat
# Out:
# Category
# FAMILY             1832
# GAME                959
# TOOLS               827
# BUSINESS            420
# MEDICAL             395
# PERSONALIZATION     376
# PRODUCTIVITY        374
# LIFESTYLE           369
# FINANCE             345
# SPORTS              325
# Name: count, dtype: int64

# %%
#i want to create data frame from the above one
df_cat=pd.DataFrame(data_copy['Category'].value_counts()[:10])

# %%
df_cat
# Out:
#                  count
# Category
# FAMILY            1832
# GAME               959
# TOOLS              827
# BUSINESS           420
# MEDICAL            395
# PERSONALIZATION    376
# PRODUCTIVITY       374
# LIFESTYLE          369
# FINANCE            345
# SPORTS             325

# %%
# Step 1: Get value counts of the 'Category' column (top 10)
df_cat = data_copy['Category'].value_counts().head(10).reset_index()

# Step 2: Rename columns
df_cat.columns = ['Category', 'Count']

# %%
df_cat
# Out:
#           Category  Count
# 0           FAMILY   1832
# 1             GAME    959
# 2            TOOLS    827
# 3         BUSINESS    420
# 4          MEDICAL    395
# 5  PERSONALIZATION    376
# 6     PRODUCTIVITY    374
# 7        LIFESTYLE    369
# 8          FINANCE    345
# 9           SPORTS    325

# %%
plt.figure(figsize=(15, 6))
sns.barplot(x='Category', y='Count', data=df_cat, palette='hls')
plt.title('Top 10 App Categories')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\monika Bhati\AppData\Local\Temp\ipykernel_15136\848513440.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Category', y='Count', data=df_cat, palette='hls')

# %% [markdown]
# # which category having largest number of installation
# # what are top 5 most installed app in each category
# # how many apps are there on google play store which get 5 rating
# # which category app users are reviewing the most
# # which category has largest of the size

# %%
# you have to write a python code for it and dyou have to visualize also

# %%
# deal with missing value and outliers

# %%
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
data_copy
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# #whenever we want to perform analysis on top of the data
#
# univariate analysis (single variable)
#
# bivariate analysis(two variable)
#
# multivariate (more than two variable)
#
# numeric var
#
# categorical var
#
# based on this factor we gonna analysis the data

# %%
data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9660 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9660 non-null   object
#  1   Category        9660 non-null   object
#  2   Rating          8197 non-null   float64
#  3   Reviews         9660 non-null   object
#  4   Size            9660 non-null   object
#  5   Installs        9660 non-null   object
#  6   Type            9659 non-null   object
#  7   Price           9660 non-null   object
#  8   Content Rating  9659 non-null   object
#  9   Genres          9660 non-null   object
#  10  Last Updated    9660 non-null   object
#  11  Current Ver     9652 non-null   object
#  12  Android Ver     9657 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 1.0+ MB

# %%
data_copy.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews Size  Installs  Type Price Content Rating  \
# 0     159  19M   10,000+  Free     0       Everyone
# 1     967  14M  500,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
#which category having largest number of installation?
#univariate analysis
#category....categorical feature
#installation..numeric

# %%
data_copy["Category"].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %%
data_copy.groupby(["Category"])["Installs"]

# %%
data_copy.groupby(["Category"])["Installs"].sum()
# Out:
# Category
# 1.9                                                                 Free
# ART_AND_DESIGN         10,000+500,000+5,000,000+50,000,000+100,000+50...
# AUTO_AND_VEHICLES      100,000+1,000,000+100,000+1,000,000+100,000+10...
# BEAUTY                 500,000+1,000,000+100,000+500,000+1,000,000+50...
# BOOKS_AND_REFERENCE    100,000,000+50,000+100,000+10,000,000+100,000,...
# BUSINESS               10,000,000+50,000,000+10,000,000+5,000,000+1,0...
# COMICS                 10,000,000+500,000+1,000,000+500,000+50,000+50...
# COMMUNICATION          1,000,000,000+1,000,000,000+10,000,000+1,000,0...
# DATING                 10,000+1,000+50+100+100+100+10,000,000+10,000,...
# EDUCATION              100,000,000+10,000,000+100,000+5,000,000+10,00...
# ENTERTAINMENT          100,000,000+1,000,000+1,000,000+10,000,000+50,...
# EVENTS                 100,000+5,000,000+500,000+50,000+5,000,000+1,0...
# FAMILY                 1,000,000+5,000,000+5,000,000+1,000,000+1,000,...
# ...

# %%
data_copy.groupby(["Category"])["Installs"].sum().sort_values(ascending=False)
# Out:
# Category
# 1.9                                                                 Free
# PRODUCTIVITY           500,000,000+10,000,000+100,000,000+10,000,000+...
# BEAUTY                 500,000+1,000,000+100,000+500,000+1,000,000+50...
# WEATHER                50,000,000+1,000,000+50,000,000+10,000+10,000,...
# PERSONALIZATION        50,000,000+1,000,000+100,000,000+5,000,000+100...
# LIBRARIES_AND_DEMO     50,000+10,000+100,000+1,000+100,000+10,000+100...
# LIFESTYLE              5,000,000+10,000,000+100,000+10,000,000+5,000,...
# BOOKS_AND_REFERENCE    100,000,000+50,000+100,000+10,000,000+100,000,...
# MAPS_AND_NAVIGATION    100,000,000+5,000,000+10,000,000+10,000,000+5,...
# EDUCATION              100,000,000+10,000,000+100,000+5,000,000+10,00...
# GAME                   100,000,000+1,000,000,000+500,000,000+10,000,0...
# ENTERTAINMENT          100,000,000+1,000,000+1,000,000+10,000,000+50,...
# EVENTS                 100,000+5,000,000+500,000+50,000+5,000,000+1,0...
# ...

# %%
data_copy.groupby(["Category"])["Installs"].sum().sort_values(ascending=False)[:10]   #will get top 10 category
# Out:
# Category
# 1.9                                                                 Free
# PRODUCTIVITY           500,000,000+10,000,000+100,000,000+10,000,000+...
# BEAUTY                 500,000+1,000,000+100,000+500,000+1,000,000+50...
# WEATHER                50,000,000+1,000,000+50,000,000+10,000+10,000,...
# PERSONALIZATION        50,000,000+1,000,000+100,000,000+5,000,000+100...
# LIBRARIES_AND_DEMO     50,000+10,000+100,000+1,000+100,000+10,000+100...
# LIFESTYLE              5,000,000+10,000,000+100,000+10,000,000+5,000,...
# BOOKS_AND_REFERENCE    100,000,000+50,000+100,000+10,000,000+100,000,...
# MAPS_AND_NAVIGATION    100,000,000+5,000,000+10,000,000+10,000,000+5,...
# EDUCATION              100,000,000+10,000,000+100,000+5,000,000+10,00...
# Name: Installs, dtype: object

# %%
df_cat_install= data_copy.groupby(["Category"])["Installs"].sum().sort_values(ascending=False)[:10]   #will get top 10 category

# %%
df_cat_install
# Out:
# Category
# 1.9                                                                 Free
# PRODUCTIVITY           500,000,000+10,000,000+100,000,000+10,000,000+...
# BEAUTY                 500,000+1,000,000+100,000+500,000+1,000,000+50...
# WEATHER                50,000,000+1,000,000+50,000,000+10,000+10,000,...
# PERSONALIZATION        50,000,000+1,000,000+100,000,000+5,000,000+100...
# LIBRARIES_AND_DEMO     50,000+10,000+100,000+1,000+100,000+10,000+100...
# LIFESTYLE              5,000,000+10,000,000+100,000+10,000,000+5,000,...
# BOOKS_AND_REFERENCE    100,000,000+50,000+100,000+10,000,000+100,000,...
# MAPS_AND_NAVIGATION    100,000,000+5,000,000+10,000,000+10,000,000+5,...
# EDUCATION              100,000,000+10,000,000+100,000+5,000,000+10,00...
# Name: Installs, dtype: object

# %%
df_cat_install=df_cat_install.reset_index()

# %%
import seaborn as  sns
sns.barplot(x="Installs",y="Category",data=df_cat_install)
# Out:
# <Axes: xlabel='Installs', ylabel='Category'>

# %%
df_cat_install
# Out:
#               Category                                           Installs
# 0                  1.9                                               Free
# 1         PRODUCTIVITY  500,000,000+10,000,000+100,000,000+10,000,000+...
# 2               BEAUTY  500,000+1,000,000+100,000+500,000+1,000,000+50...
# 3              WEATHER  50,000,000+1,000,000+50,000,000+10,000+10,000,...
# 4      PERSONALIZATION  50,000,000+1,000,000+100,000,000+5,000,000+100...
# 5   LIBRARIES_AND_DEMO  50,000+10,000+100,000+1,000+100,000+10,000+100...
# 6            LIFESTYLE  5,000,000+10,000,000+100,000+10,000,000+5,000,...
# 7  BOOKS_AND_REFERENCE  100,000,000+50,000+100,000+10,000,000+100,000,...
# 8  MAPS_AND_NAVIGATION  100,000,000+5,000,000+10,000,000+10,000,000+5,...
# 9            EDUCATION  100,000,000+10,000,000+100,000+5,000,000+10,00...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(14,10))
sns.set_context("talk")
sns.set_style("darkgrid")

ax=sns.barplot(x="Installs",y="Category",data=df_cat_install)
ax.set_xlabel("No. of Installations in Billion")
ax.set_ylabel("")
ax.set_title("Most popular categories in play store",size=20)
# Out:
# Text(0.5, 1.0, 'Most popular categories in play store')

# %%
#what are top 5 most installed app in each category
data_copy.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews Size  Installs  Type Price Content Rating  \
# 0     159  19M   10,000+  Free     0       Everyone
# 1     967  14M  500,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
#multivariate analysis
#category,installation,app
data_copy.groupby(["Category","App"])["Installs"]

# %%
data_copy.groupby(["Category","App"])["Installs"].sum()
# Out:
# Category        App
# 1.9             Life Made WI-Fi Touchscreen Photo Frame                                                     Free
# ART_AND_DESIGN  350 Diy Room Decor Ideas                                                                 10,000+
#                 3D Color Pixel by Number - Sandbox Art Coloring                                         100,000+
#                 AJ Styles HD Wallpapers                                                                   5,000+
#                 AJ Styles Wallpaper 2018 - AJ Styles HD Wallpaper                                         1,000+
#                                                                                                         ...
# WEATHER         Yahoo Weather                                                                        10,000,000+
#                 Yahoo! Weather for SH Forecast for understanding the approach of rain clouds Free     1,000,000+
# ...

# %%
df=data_copy.groupby(["Category","App"])["Installs"].sum().reset_index()

# %%
df[df["Category"]== "ART_AND_DESIGN"].sort_values(ascending=False,by="Installs")[:5]
# Out:
#           Category                                             App  Installs
# 52  ART_AND_DESIGN         Superheroes Wallpapers | 4K Backgrounds  500,000+
# 58  ART_AND_DESIGN  UNICORN - Color By Number & Pixel Art Coloring  500,000+
# 25  ART_AND_DESIGN   How To Color Disney Princess - Coloring Pages  500,000+
# 43  ART_AND_DESIGN    Photo Designer - Write your name with shapes  500,000+
# 12  ART_AND_DESIGN                   Colorfit - Drawing & Coloring  500,000+

# %%
 df[df["Category"]== "GAME"].sort_values(ascending=False,by="Installs")[:5]
# Out:
#      Category                                   App      Installs
# 4629     GAME                                   Pou  500,000,000+
# 4581     GAME                        My Talking Tom  500,000,000+
# 4803     GAME                          Temple Run 2  500,000,000+
# 4168     GAME                      Candy Crush Saga  500,000,000+
# 4633     GAME  Project Grand Auto Town Sandbox Beta      500,000+

# %%
#what are top 5 most installed app in each category
data_copy["Category"].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %%
df[df["Category"]== "ART_AND_DESIGN"].sort_values(ascending=False,by="Installs")[:5]
df2=df[df.Category == apps].sort_values(ascending=False,by="Installs")[:5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[70], line 2
#       1 df[df["Category"]== "ART_AND_DESIGN"].sort_values(ascending=False,by="Installs")[:5]
# ----> 2 df2=df[df.Category == apps].sort_values(ascending=False,by="Installs")[:5]
#
# NameError: name 'apps' is not defined

# %%
df2=df[df.Category == "GAME"]

# %%
df2.head(5)
# Out:
#      Category                              App     Installs
# 3961     GAME  1LINE – One Line with One Touch  10,000,000+
# 3962     GAME      2-Player Co-op Zombie Shoot       1,000+
# 3963     GAME                           211:CK          10+
# 3964     GAME                      211:CK Lite          10+
# 3965     GAME                       4 in a Row     500,000+

# %%
#what are top 5 most installed app in each category
apps=['GAME','COMMUNICATION','PRODUCTIVITY','SOCIAL']
sns.set_context("poster")
sns.set_style("darkgrid")

plt.figure(figsize=(40,30))

for i ,app in enumerate(apps):
    df2=df[df.Category == app].sort_values(ascending=False,by="Installs")[:5]
    df3 = df2.head(5)
    plt.subplot(4,2,i+1)
    sns.barplot(data=df3,x='Installs',y='App')
    plt.xlabel('Installation in Millions')
    plt.ylabel(' ')
    plt.title(app,size=20)

plt.tight_layout()
plt.subplots_adjust(hspace=.3)
plt.show()

# %%
apps
# Out:
# ['GAME', 'COMMUNICATION', 'PRODUCTIVITY', 'SOCIAL']

# %%
#how many apps are there on google play store which get 5 rating
data_copy.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews Size  Installs  Type Price Content Rating  \
# 0     159  19M   10,000+  Free     0       Everyone
# 1     967  14M  500,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
data_copy[data_copy['Rating']==5    #giving data which has 5 rating
# Out:
#   Cell In[76], line 1
#     data_copy[data_copy['Rating']==5    #giving data which has 5 rating
#                                                                        ^
# _IncompleteInputError: incomplete input

# %%
data_copy[data_copy['Rating']==5]['App']
# Out:
# 329                    Hojiboy Tojiboyev Life Hacks
# 612                   American Girls Mobile Numbers
# 615                                    Awake Dating
# 633                           Spine- The dating app
# 636      Girls Live Talk - Free Text and Video Chat
#                             ...
# 10721                             Mad Dash Fo' Cash
# 10742                         GKPB FP Online Church
# 10776                              Monster Ride Pro
# 10820                               Fr. Daoud Lamei
# 10837              Fr. Mike Schmitz Audio Teachings
# Name: App, Length: 271, dtype: object

# %%
len(data_copy[data_copy['Rating']==5]['App'])
# Out:
# 271

# %%
(data_copy['Rating']==5).sum()
# Out:
# np.int64(271)

# %%
l=data_copy.groupby(['Rating','App'])['Rating'].sum().value_counts()

plt.figure(figsize=(30,30))
plt.pie(l,labels=l.index,autopct='%1.1f%%')
plt.show()

# %%
data_copy.groupby(['App'])["Rating"].sum().reset_index()
# Out:
#                                                    App  Rating
# 0                 "i DT" Fútbol. Todos Somos Técnicos.     0.0
# 1                        +Download 4 Instagram Twitter     4.5
# 2                           - Free Comics - Comic Apps     3.5
# 3                                                   .R     4.5
# 4                                               /u/app     4.7
# ...                                                ...     ...
# 9655                           뽕티비 - 개인방송, 인터넷방송, BJ방송     0.0
# 9656                                        💎 I'm rich     3.8
# 9657     💘 WhatsLov: Smileys of love, stickers and GIF     4.6
# 9658  📏 Smart Ruler ↔️ cm/inch measuring for homework!     4.0
# 9659  🔥 Football Wallpapers 4K | Full HD Backgrounds 😍     4.7
#
# [9660 rows x 2 columns]

# %%
rating=data_copy.groupby(['App'])["Rating"].sum().shape

# %%
rating
# Out:
# (9660,)

# %%
rating=data_copy.groupby(['App'])["Rating"].mean().sort_values(ascending=False).reset_index()

# %%
rating[rating.Rating==5.0]
# Out:
#                                App  Rating
# 1                   FHR 5-Tier 2.0     5.0
# 2           Quran Khmer Offline AY     5.0
# 3    R Programing Offline Tutorial     5.0
# 4                    The CJ Rubric     5.0
# 5                   FK Dedinje BGD     5.0
# ..                             ...     ...
# 267      Lyrics of Ek Paheli Leela     5.0
# 268                     Master E.K     5.0
# 269               Monster Ride Pro     5.0
# 270                   Morse Player     5.0
# 271            BV Sridhara Maharaj     5.0
#
# [271 rows x 2 columns]

# %%
data_copy.shape
# Out:
# (9660, 13)

# %%
#which category app users are reviewing the most

# %%
data_copy.head(2)    #multivariate analysis
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews Size  Installs  Type Price Content Rating  \
# 0     159  19M   10,000+  Free     0       Everyone
# 1     967  14M  500,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
df2=data_copy.groupby(["Category","App"])["Reviews"].sum().reset_index()

# %%
df2[df2["Category"]=="SOCIAL"].sort_values(ascending=False,by="Reviews").to_csv("game_top_reviews.csv",index=False)

# %%
df2[df2["Category"]=="GAME"].sort_values(ascending=False,by="Reviews").to_csv("game_top_reviews.csv",index=False)

# %%
l = data_copy.groupby('Category')['Reviews'].max().sort_values(ascending=False)

# %%
l

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Grouping: max reviews per category
l = data_copy.groupby('Category')['Reviews'].max().sort_values(ascending=False)

# Plotting
plt.figure(figsize=(20, 15))
sns.barplot(y=l.index, x=l.values, palette='viridis')  # x=values, y=category names
plt.show()

# %%
def replace_outliers_with_median(x):
    median=x.median()
    std=x.std()
    lower=median - 3*std
    upper=median +3*std
    x[(x < lower) | (x > upper)] = median
    return x
df = df.apply( replace_outliers_with_median)

# %%
df

# %%
numeric_feature

# %%
df=data_copy[numeric_feature]

# %%
plt.figure(figsize=(10,10))
sns.boxplot(x="Category",y="Rating",data=df)
plt.xticks(size=15,rotation=90)
plt.show()
