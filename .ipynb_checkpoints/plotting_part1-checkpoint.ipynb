# %% [markdown]
# # 5 core steps for the machine learning
# # 1. Data ingestion(Data Engineer)
# # 2. Data Analysis (excel,powerbi.tableu)
# # 3. Data preprocessing
# # 4. Data Modeling
# # 5. Model Evalution

# %% [markdown]
# # data analysis with the python(EDA)
#
# pandas
#
# matplotlib
#
# seaborn
#
# bokeh
#
# plotly
#
# cufflinks

# %%
import pandas as pd

# %%
data= pd.read_csv("https://raw.githubusercontent.com/sunnysavita10/Statistics-With-Python-CompleteGuide/refs/heads/main/Iris.csv")

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
line
scatter plot
bar plot
histogram
pie
box
violin
heatmap
3d plot

# %%
data['SepalLengthCm'].plot()
data['SepalWidthCm'].plot()
data['PetalLengthCm'].plot()
data['PetalWidthCm'].plot()
# Out:
# <Axes: >

# %%
data['SepalLengthCm'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
data['PetalLengthCm'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
line:line plot(default)
-'bar':vertical bar plot
-'barh':horizontal bar plot
-'hist':histogram
-'box':boxplot
-'kde':kernel density estimation plot
-'density':same as 'kde'
-'areas':area plot
-'pie':pie plot
-'scatter':scatter plot(dataframe only)
-'hexbin':hexbin plot(dataframe only)

# %%
univariate-single variable(column)

bivariate - two columns

multivariate- more than 3 columns

# %%
data2=pd.read_csv('https://raw.githubusercontent.com/sunnysavita10/Statistics-With-Python-CompleteGuide/refs/heads/main/Titanic.csv')

# %%
data2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
x=data2["Age"]
y=data2["Fare"]

fig,ax=plt.subplots()

ax.scatter(x,y)

ax.set_xlabel("Age")
ax.set_ylabel("Fare")
ax.set_title("scatter plot")
plt.show()

# %%
# why we use bar plot?
univariate
bivariarte
1. x-num y-num
2. x-cat t-cat
3. x-num y-cat(vice versa)

# %%
x=["A","B","C","D","E"]
plt.bar(x,height=10.2)
# Out:
# <BarContainer object of 5 artists>

# %%
x=data2["Pclass"]
y=data2["Fare"]

fig,ax=plt.subplots()

ax.bar(x,y)

ax.set_xlabel("Pclass")
ax.set_ylabel("Fare")
ax.set_title("Bar plot")
plt.show()

# %%
x=data2["Pclass"]
y=data2["Age"]

fig,ax=plt.subplots()

ax.bar(x,y)

ax.set_xlabel("Pclass")
ax.set_ylabel("Age")
ax.set_title("Bar plot")
plt.show()

# %%
#univariate 
x=data2["Age"]

fig,ax=plt.subplots()

ax.hist(x)

ax.set_xlabel("Age")
ax.set_ylabel("Frequency")
ax.set_title("hist plot")
plt.show()

# %%
groupby()

# %%
x=[15,60,65,43]
y=["A","B","C","D"]

fig,ax=plt.subplots()

ax.pie(x,labels=y,autopct='%0.2f%%')

ax.set_title("piechart")
plt.show()

# %%
data2["Fare"].max()
# Out:
# np.float64(512.3292)

# %%
data2["Fare"].min()
# Out:
# np.float64(0.0)

# %%
x=["A","B","C","D","E"]
y=[5,6,7,4,3]

fig,ax=plt.subplots()

ax.bar(x,y)

ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_title("Bar plot")

plt.show()

# %%
data2['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
data2['Pclass'].plot(kind='bar')
# Out:
# <Axes: >

# %%
data2['Pclass'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
d=data2['Pclass'].value_counts()

# %%
d.plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
d.plot(kind='bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.linspace(0,10,100)

# %%
y=np.sin(x)

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
plt.plot(x)

# %%
plt.plot(y)

# %%
plt.plot(y)
plt.show()

# %%
X=np.linspace(0,10,100)

# %%
y=np.sin(x)

# %%
fig,ax= plt.subplots()
ax.plot(X,y)

# %%
X=np.linspace(0,10,100)
y=np.sin(x)

fig,ax= plt.subplots()
ax.plot(X,y)

ax.set(xlabel='x',ylabel='sin(x)',title='sine wave')
ax.grid()

plt.show()

# %%
 x=np.random.randn(100)
 y=np.random.randn(100)

# %%
fig,ax=plt.subplots()

# %%
ax.scatter(x,y)

# %%
x=np.random.randn(100)
y=np.random.randn(100)

fig,ax=plt.subplots()

ax.scatter(x,y)

ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")
ax.set_title("scatter plot")
plt.show()

# %% [markdown]
# # 3D plot

# %%
np.outer(np.linspace(-2,2,50),np.ones(50))
# Out:
# array([[-2.        , -2.        , -2.        , ..., -2.        ,
#         -2.        , -2.        ],
#        [-1.91836735, -1.91836735, -1.91836735, ..., -1.91836735,
#         -1.91836735, -1.91836735],
#        [-1.83673469, -1.83673469, -1.83673469, ..., -1.83673469,
#         -1.83673469, -1.83673469],
#        ...,
#        [ 1.83673469,  1.83673469,  1.83673469, ...,  1.83673469,
#          1.83673469,  1.83673469],
#        [ 1.91836735,  1.91836735,  1.91836735, ...,  1.91836735,
#          1.91836735,  1.91836735],
#        [ 2.        ,  2.        ,  2.        , ...,  2.        ,
#          2.        ,  2.        ]], shape=(50, 50))

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits import mplot3d

x=np.outer(np.linspace(-2,2,50),np.ones(50))
y=x.copy().T
z=np.cos(x**2+y**2)

fig=plt.figure()
ax=fig.add_subplot(111,projection='3d')

#plot the data
ax.plot_surface(x,y,z)

#set the axis labels and title
ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')
ax.set_zlabel('z-axis')
ax.set_title('3D plot')

#show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns

sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
df=sns.load_dataset("tips")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x="total_bill",y="tip",data=df)

# %%
#bivariate
#x-num y-num

sns.relplot(x="total_bill",y="tip",data=df,kind="line")

# %%
sns.boxplot(x="day",y="total_bill",data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.countplot(x="smoker",data=df)
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.countplot(x="time",data=df)
# Out:
# <Axes: xlabel='time', ylabel='count'>

# %%
sns.distplot(df["total_bill"])
# Out:
# C:\Users\monika Bhati\AppData\Local\Temp\ipykernel_24856\2943580123.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["total_bill"])
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.histplot(df["total_bill"])
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.catplot(x="day",y="total_bill",kind="bar",data=df)

# %%
sns.lineplot(x="Age",y="Pclass",data=data2)
# Out:
# <Axes: xlabel='Age', ylabel='Pclass'>

# %%
sns.lineplot(data=df ,x="total_bill",y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>
